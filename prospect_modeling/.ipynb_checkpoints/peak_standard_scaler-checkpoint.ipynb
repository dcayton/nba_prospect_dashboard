# %%
import numpy as np
import pandas as pd

import os
import sys

current = os.path.dirname(os.path.realpath("peak_standard_scaler"))
parent = os.path.dirname(current)

pd.set_option("display.max_columns", 150)
peaks = pd.read_csv(parent + "/player_data/peaks.csv")
peaks.head()
# Out:
#   peak_Player-additional  peak_Age  peak_G  peak_GS  peak_MP  peak_FG  \
# 0              abdulta01     27.00   24.00    12.00    18.38     6.60
# 1              abdursh01     26.00   81.00    71.33    36.13    10.07
# 2              abrinal01     24.00   58.00     5.33    16.53     5.20
# 3              ackeral01     26.00   25.00     0.00     7.96     7.90
# 4                acyqu01     23.33   50.33     9.67    13.36     5.67
#
#    peak_FGA  peak_FG%  peak_3P  peak_3PA  peak_3P%  peak_2P  peak_2PA  \
# 0      17.7      0.37     0.10      0.20      0.50     6.50     17.40
# 1      21.3      0.47     0.33      0.97      0.30     9.73     20.37
# 2      13.7      0.38     3.80     10.43      0.36     1.50      3.30
# 3      20.0      0.40     1.80      5.30      0.35     6.10     14.80
# 4      10.6      0.53     0.47      1.30      0.38     5.20      9.30
#
#    peak_2P%  peak_FT  peak_FTA  peak_FT%  peak_ORB  peak_DRB  peak_TRB  \
# 0      0.37     2.90      4.00      0.73      4.90      5.20     10.10
# 1      0.48     7.50      9.00      0.84      3.43      8.77     12.20
# 2      0.46     1.57      1.77      0.89      0.77      3.50      4.27
# 3      0.41     1.30      2.60      0.50      2.10      4.20      6.30
# 4      0.55     3.20      4.27      0.74      4.20      7.57     11.77
#
#    peak_AST  peak_STL  peak_BLK  peak_TOV  peak_PF  peak_PTS  peak_ORtg  \
# 0      2.90      2.40      1.20      3.20     6.70     16.20      90.00
# 1      3.93      1.53      0.90      3.90     4.10     27.93     108.67
# 2      1.57      1.57      0.43      1.23     4.97     15.80     110.67
# 3      3.20      1.30      1.10      1.80     2.40     19.00      94.00
# 4      1.63      1.67      1.73      1.97     7.03     15.03     117.67
#
#    peak_DRtg  peak_AST_2_TOV  peak_AST_2_FG  peak_PPP  peak_Season  peak_PER  \
# 0     107.00            0.91           0.16      0.71      2001.00      9.80
# 1     105.33            1.01           0.18      0.96      2002.00     19.87
# 2     110.33            1.27           0.11      1.00      2017.00      8.47
# 3     114.00            1.78           0.16      0.83      2008.00     10.40
# 4     106.67            0.87           0.16      1.03      2013.33     13.57
#
#    peak_TS%  peak_3PAr  peak_FTr  peak_ORB%  peak_DRB%  peak_TRB%  peak_AST%  \
# 0      0.42       0.01      0.22      10.10      11.60      10.80       8.80
# 1      0.55       0.05      0.42       7.50      18.67      13.13      14.03
# 2      0.54       0.76      0.13       1.77       7.93       4.77       4.40
# 3      0.45       0.26      0.13       4.50       9.60       7.00      10.20
# 4      0.59       0.12      0.40       9.30      17.07      13.13       4.83
#
#    peak_STL%  peak_BLK%  peak_TOV%  peak_USG%  peak_OWS  peak_DWS  peak_WS  \
# 0       2.40       1.70      14.30      19.10     -0.30      0.30     0.00
# 1       1.53       1.30      13.33      25.20      5.87      2.47     8.33
# 2       1.57       0.70       7.87      13.60      0.87      0.83     1.63
# 3       1.30       1.50       8.00      20.10     -0.10      0.10     0.00
# 4       1.67       2.73      13.67      12.63      1.03      0.67     1.70
#
#    peak_WS/48  peak_OBPM  peak_DBPM  peak_BPM  peak_VORP  peak_Dist.  \
# 0       -0.00      -3.40      -0.30     -3.70      -0.20        8.10
# 1        0.14       2.17      -0.53      1.63       2.67        8.47
# 2        0.08      -2.30       0.13     -2.13       0.00       21.07
# 3       -0.01      -1.80      -1.70     -3.60      -0.10       14.70
# 4        0.13      -1.23       0.67     -0.57       0.23        8.60
#
#    peak_2P_prop  peak_0-3_prop  peak_3-10_prop  peak_10-16_prop  \
# 0          0.99           0.40            0.22             0.13
# 1          0.95           0.34            0.29             0.13
# 2          0.24           0.12            0.04             0.03
# 3          0.74           0.22            0.07             0.12
# 4          0.88           0.50            0.14             0.05
#
#    peak_16-3P_prop  peak_3P_prop  peak_2P_fg%  peak_0-3_fg%  peak_3-10_fg%  \
# 0             0.24          0.01         0.37          0.55           0.44
# 1             0.20          0.05         0.48          0.60           0.43
# 2             0.05          0.76         0.46          0.53           0.40
# 3             0.33          0.26         0.41          0.29           0.40
# 4             0.19          0.12         0.55          0.66           0.42
#
#    peak_10-16_fg%  peak_16-3P_fg%  peak_3P_fg%  peak_2P_%astd  peak_3P_%astd  \
# 0            0.21            0.11         0.50           0.67           1.00
# 1            0.41            0.39         0.30           0.53           0.96
# 2            0.43            0.34         0.36           0.65           0.97
# 3            0.56            0.44         0.35           0.48           0.71
# 4            0.48            0.39         0.38           0.71           0.98
#
#    peak_dunk_%FGA  peak_dunk_#  peak_corner_%3PA  peak_corner_3P%  \
# 0            0.07         8.00              0.00             0.00
# 1            0.08        87.67              0.25             0.42
# 2            0.02         5.00              0.23             0.39
# 3            0.01         0.00              0.45             0.22
# 4            0.22        29.00              0.50             0.61
#
#    peak_heave_Att.  peak_heave_#
# 0             0.00           0.0
# 1             0.67           0.0
# 2             1.67           0.0
# 3             0.00           0.0
# 4             0.00           0.0

# %%
peaks_scaler_stats = ["peak_AST_2_TOV", "peak_AST_2_FG", "peak_AST%", "peak_TOV%", "peak_USG%", "peak_PPP", "peak_2P_prop",
                      "peak_0-3_prop", "peak_3-10_prop", "peak_10-16_prop", "peak_16-3P_prop", "peak_3P_prop",
                      "peak_corner_%3PA", "peak_2P_%astd", "peak_3P_%astd", "peak_0-3_fg%",
                      "peak_3-10_fg%", "peak_10-16_fg%", "peak_16-3P_fg%", "peak_3P_fg%", "peak_corner_3P%",
                      "peak_STL%", "peak_BLK%", "peak_ORB%", "peak_DRB%"]
peaks_scale = peaks.loc[:,peaks_scaler_stats]

# %%
peaks_scale["peak_3P_%astd"] = peaks_scale["peak_3P_prop"] * peaks_scale["peak_3P_%astd"]
peaks_scale["peak_2P_%astd"] = peaks_scale["peak_2P_prop"] * peaks_scale["peak_2P_%astd"]

peaks_scale["peak_corner_%3PA"] = peaks_scale["peak_corner_%3PA"] * peaks_scale["peak_3P_prop"]
peaks_scale["peak_3P_prop_not_corner"] = peaks_scale["peak_3P_prop"] - peaks_scale["peak_corner_%3PA"]

peaks_scale = peaks_scale.drop(["peak_3P_prop", "peak_2P_prop"], axis=1)

# %%
peaks_scale.values
# Out:
# array([[9.100e-01, 1.600e-01, 8.800e+00, ..., 1.010e+01, 1.160e+01,
#         1.000e-02],
#        [1.010e+00, 1.800e-01, 1.403e+01, ..., 7.500e+00, 1.867e+01,
#         3.750e-02],
#        [1.270e+00, 1.100e-01, 4.400e+00, ..., 1.770e+00, 7.930e+00,
#         5.852e-01],
#        ...,
#        [1.040e+00, 1.500e-01, 7.700e+00, ..., 1.030e+01, 1.983e+01,
#         2.250e-02],
#        [5.900e-01, 8.000e-02, 5.100e+00, ..., 5.400e+00, 1.535e+01,
#         3.610e-01],
#        [1.170e+00, 2.300e-01, 8.930e+00, ..., 1.410e+01, 2.417e+01,
#         0.000e+00]])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
peaks_scale = scaler.fit_transform(peaks_scale.values)

# %%
import joblib
joblib.dump(scaler, "prospect_models/peak_scaler.sav")
# Out:
# ['prospect_models/peak_scaler.sav']
